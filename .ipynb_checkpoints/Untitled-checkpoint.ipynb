# %%
import json

# %%
data = json.load(open("data.json"))
data
# Out:
# {'diag': {'Pericardial disease NOS': 0,
#   'Pleural effusion NOS': 1,
#   'Cardiogenic shock': 2,
#   'Hypotension NOS': 3,
#   'Depressive disorder NEC': 4,
#   'Cervical disc displacmnt': 5,
#   'Joint pain-l/leg': 6,
#   'Hyperlipidemia NEC/NOS': 7,
#   'Secundum atrial sept def': 8,
#   'Iatrogenc hypotnsion NEC': 9,
#   'Hx-circulatory dis NEC': 10,
#   'Subendo infarct, initial': 11,
#   'Blood in stool': 12,
#   'Acute kidney failure NOS': 13,
#   'Hyp kid NOS w cr kid V': 14,
#   'CHF NOS': 15,
#   'Compression of vein': 16,
#   'Food/vomit pneumonitis': 17,
#   'Atrial fibrillation': 18,
#   'Parox ventric tachycard': 19,
#   'Crnry athrscl natve vssl': 20,
#   'DMII wo cmp nt st uncntr': 21,
#   'Anemia in chr kidney dis': 22,
#   'Candidias urogenital NEC': 23,
#   'Pure hypercholesterolem': 24,
#   'Gout NOS': 25,
#   'Hx-prostatic malignancy': 26,
#   'Late effect CV dis NEC': 27,
#   'Septicemia NEC': 28,
#   'Septic shock': 29,
#   'Pressure ulcer, site NEC': 30,
# ...

# %%
data["med"]
# Out:
# {'0': '4239',
#  '1': '5119',
#  '2': '78551',
#  '3': '4589',
#  '4': '311',
#  '5': '7220',
#  '6': '71946',
#  '7': '2724',
#  '8': '7455',
#  '9': '45829',
#  '10': 'V1259',
#  '11': '41071',
#  '12': '5781',
#  '13': '5849',
#  '14': '40391',
#  '15': '4280',
#  '16': '4592',
#  '17': '5070',
#  '18': '42731',
#  '19': '4271',
#  '20': '41401',
#  '21': '25000',
#  '22': '28521',
#  '23': '1122',
#  '24': '2720',
#  '25': '2749',
#  '26': 'V1046',
#  '27': '43889',
#  '28': '0388',
#  '29': '78552',
#  '30': '70709',
#  '31': '6823',
#  '32': '99859',
#  '33': '00845',
#  '34': '5720',
#  '35': '99592',
#  '36': 'V0980',
#  '37': '2859',
#  '38': '185',
#  '39': '4439',
#  '40': '2449',
#  '41': 'E8788',
#  '42': '2252',
#  '43': '3485',
#  '44': '78039',
#  '45': '4241',
#  '46': '4019',
#  '47': 'V4581',
#  '48': 'V4579',
#  '49': 'V1582',
#  '50': '4111',
#  '51': 'V4582',
#  '52': '60000',
#  '53': '3899',
#  '54': '4254',
#  '55': '9971',
#  '56': '4260',
#  '57': 'E8790',
# ...

# %%
pro = [{"name": k, "index": v}
    for k, v in data["pro"].items()
      ]
pro
# Out:
# [{'name': 'Pericardial disease NOS', 'index': 0},
#  {'name': 'Pleural effusion NOS', 'index': 1},
#  {'name': 'Cardiogenic shock', 'index': 2},
#  {'name': 'Hypotension NOS', 'index': 3},
#  {'name': 'Depressive disorder NEC', 'index': 4},
#  {'name': 'Cervical disc displacmnt', 'index': 5},
#  {'name': 'Joint pain-l/leg', 'index': 6},
#  {'name': 'Hyperlipidemia NEC/NOS', 'index': 7},
#  {'name': 'Secundum atrial sept def', 'index': 8},
#  {'name': 'Iatrogenc hypotnsion NEC', 'index': 9},
#  {'name': 'Hx-circulatory dis NEC', 'index': 10},
#  {'name': 'Subendo infarct, initial', 'index': 11},
#  {'name': 'Blood in stool', 'index': 12},
#  {'name': 'Acute kidney failure NOS', 'index': 13},
#  {'name': 'Hyp kid NOS w cr kid V', 'index': 14},
#  {'name': 'CHF NOS', 'index': 15},
#  {'name': 'Compression of vein', 'index': 16},
#  {'name': 'Food/vomit pneumonitis', 'index': 17},
#  {'name': 'Atrial fibrillation', 'index': 18},
#  {'name': 'Parox ventric tachycard', 'index': 19},
# ...

# %%
with open('diagnosis.json', 'w') as fp:
    json.dump(diag, fp)
